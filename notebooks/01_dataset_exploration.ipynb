# %% [markdown]
# # 01 Dataset Exploration
#
# Explore downloaded Kaggle files in `data/raw/`, inspect columns, and choose the preparation strategy.

# %%
from pathlib import Path
from src.data.dataset_loader import discover_data_files, read_table

files = discover_data_files(Path('data/raw'))
files[:10]

# %%
if files:
    df = read_table(files[0])
    display(df.head())
    display(df.dtypes)
    print(df.shape)
