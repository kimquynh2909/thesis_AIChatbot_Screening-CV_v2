# %% [markdown]
# # 05 Evaluation
#
# Run ranking evaluation on prepared candidate-job pairs.

# %%
from pathlib import Path
import pandas as pd
from src.evaluation.benchmark import run_benchmark

pairs = Path('data/processed/test_pairs.csv')
if pairs.exists():
    comparison = run_benchmark(pairs, ['tfidf', 'bm25'], limit_jobs=20)
    display(comparison)
else:
    print('Prepare data/processed/test_pairs.csv before running this notebook.')
